# %% [markdown]
# <a href="https://colab.research.google.com/github/selveszero/GomoBot/blob/main/gomobot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/selveszero/Deep-Q-Learning-for-Gomoku.git
# Out:
# Cloning into 'Deep-Q-Learning-for-Gomoku'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.

# %%
# %cd Deep-Q-Learning-for-Gomoku/
# Out:
# /content/Deep-Q-Learning-for-Gomoku

# %%
# !python main.py

# %%
# !python agents_play.py --filename1 'output/v_1/epoch_100/agent_1.pkl' --filename2 'output/v_1/epoch_100/agent_1.pkl'
# Out:
# 2021-04-25 16:43:34.649257: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-25 16:43:36.602772: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-25 16:43:36.604021: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-25 16:43:36.625764: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-25 16:43:36.626598: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/junxiaosong/AlphaZero_Gomoku.git
# Out:
# Cloning into 'AlphaZero_Gomoku'...
# remote: Enumerating objects: 176, done.
# remote: Total 176 (delta 0), reused 0 (delta 0), pack-reused 176
# Receiving objects: 100% (176/176), 8.09 MiB | 8.08 MiB/s, done.
# Resolving deltas: 100% (92/92), done.

# %%
# %cd AlphaZero_Gomoku
# Out:
# /content/AlphaZero_Gomoku

# %%
# !python human_play.py
# Out:
# Player 1 with X
# Player 2 with O
#
#        0       1       2       3       4       5       6       7
#
#    7   _       _       _       _       _       _       _       _
#
#
#    6   _       _       _       _       _       _       _       _
#
#
#    5   _       _       _       _       _       _       _       _
#
#
#    4   _       _       _       _       _       _       _       _
#
#
#    3   _       _       _       _       _       _       _       _
#
#
#    2   _       _       _       _       _       _       _       _
#
#
#    1   _       _       _       _       _       _       _       _
#
#
#    0   _       _       _       _       _       _       _       _
#
#
# Player 1 with X
# Player 2 with O
#
#        0       1       2       3       4       5       6       7
#
#    7   _       _       _       _       _       _       _       _
#
#
#    6   _       _       _       _       _       _       _       _
#
#
#    5   _       _       _       _       _       _       _       _
#
#
# ...

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/slcz/gomoku-deep-learning.git
# Out:
# Cloning into 'gomoku-deep-learning'...
# remote: Enumerating objects: 248, done.
# remote: Total 248 (delta 0), reused 0 (delta 0), pack-reused 248
# Receiving objects: 100% (248/248), 120.07 MiB | 40.52 MiB/s, done.
# Resolving deltas: 100% (141/141), done.

# %%
# %cd gomoku-deep-learning
# Out:
# /content/gomoku-deep-learning

# %%
# !python gomoku.py --agent1 web --agent2 dqntest --agent2_model G20 --web --boardsize 11
# Out:
# 2021-04-24 22:56:25.931881: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Traceback (most recent call last):
#   File "gomoku.py", line 8, in <module>
#     from dqn import (DqntrainAgent, DqntestAgent, MontecarloAgent, CloneNetworks)
#   File "/content/gomoku-deep-learning/dqn.py", line 18, in <module>
#     FLAGS = tf.app.flags.FLAGS
# AttributeError: module 'tensorflow' has no attribute 'app'

# %%
# %cd ..
# Out:
# /content

# %%
# !git clone https://github.com/selveszero/gomoku.git
# Out:
# Cloning into 'gomoku'...
# remote: Enumerating objects: 65, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 65 (delta 36), reused 61 (delta 34), pack-reused 0
# Unpacking objects: 100% (65/65), done.

# %%
# %cd gomoku
# Out:
# /content/gomoku

# %%
# !python game.py 6 4 100
# Out:
# ------------------------------------------
#              Welcome to Gomoku
# ------------------------------------------
# Modes:
#  1. Human vs. Human
#  2. Tournament
#  3. Agent vs. Agent
#  4. Random vs. Agent
# ------------------------------------------
# Choose Mode: 2
# Start:
#  1. My Agent Starts (X)
#  2. Other Agent Starts (O)
# Choose Starting Player: 1
# ------------------------------------------
#               Current Board
# ------------------------------------------
# . . . . . .
# . . . . . .
# . X . . . .
# . . . . . .
# . . . . . .
# . . . . . .
# ------------------------------------------
# Initial Move: (2, 1)
# ------------------------------------------
# Player O's Turn
# Move: 2 2
# ------------------------------------------
#               Current Board
# ------------------------------------------
# . . . . . .
# . . . . . .
# . X O . . .
# . . . . . .
# . . . . . .
# . . . . . .
# ------------------------------------------
# ...
